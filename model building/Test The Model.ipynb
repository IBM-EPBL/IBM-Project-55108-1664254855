# %%
import numpy as np #used for numerical analysis
import tensorflow #open source used for both ML and DL for computatio
from tensorflow.keras.models import Sequential #it is a palin stack of layer 
from tensorflow.keras.layers import Layer #Alayer consists of a tensor-in tensor-out computation function
from tensorflow.keras.layers import Dense,Flatten #flattening the input or change the dimension
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout #convolution layer , MaxPooling2D-for downsampling the image
from keras.preprocessing.image import ImageDataGenerator

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd/content/drive/mydrive

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale = 1./255)
x_train = train_datagen.flow_from_directory(r'/content/drive/MyDrive/TRAIN_SET',target_size = (64,64) ,batch_size = 5,color_mode='rgb',class_mode = 'sparse')
x_test = test_datagen.flow_from_directory(r'/content/drive/MyDrive/TEST_SET',target_size = (64,64) ,batch_size = 5,color_mode='rgb',class_mode = 'sparse')
# Out:
# Found 2626 images belonging to 5 classes.
# Found 929 images belonging to 5 classes.

# %%
model=Sequential()

# %%
model.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))

# %%
model.add(MaxPooling2D(pool_size =(2,2)))

# %%
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size =(2,2)))
model.add(Flatten())

# %%
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=128,activation='softmax'))

# %%
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7f806d35f450>>

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(
generator=x_train,steps_per_epoch=len(x_train),
epochs=20,validation_data=x_test,validation_steps=len(x_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/20
# 526/526 [==============================] - 1685s 3s/step - loss: 0.2247 - accuracy: 0.9292 - val_loss: 4.6773 - val_accuracy: 0.4080
# Epoch 2/20
# 526/526 [==============================] - 29s 54ms/step - loss: 5.4095e-04 - accuracy: 1.0000 - val_loss: 5.1438 - val_accuracy: 0.4327
# Epoch 3/20
# 526/526 [==============================] - 31s 59ms/step - loss: 3.0797e-04 - accuracy: 1.0000 - val_loss: 5.5030 - val_accuracy: 0.4392
# Epoch 4/20
# 526/526 [==============================] - 29s 55ms/step - loss: 7.1946e-05 - accuracy: 1.0000 - val_loss: 6.0729 - val_accuracy: 0.4284
# Epoch 5/20
# 526/526 [==============================] - 31s 59ms/step - loss: 5.6177e-05 - accuracy: 1.0000 - val_loss: 6.3361 - val_accuracy: 0.4381
# Epoch 6/20
# 526/526 [==============================] - 29s 55ms/step - loss: 0.0591 - accuracy: 0.9821 - val_loss: 5.6986 - val_accuracy: 0.4747
# Epoch 7/20
# 526/526 [==============================] - 30s 58ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 5.6319 - val_accuracy: 0.4672
# Epoch 8/20
# 526/526 [==============================] - 28s 54ms/step - loss: 0.0139 - accuracy: 0.9966 - val_loss: 6.4103 - val_accuracy: 0.4833
# Epoch 9/20
# 526/526 [==============================] - 31s 58ms/step - loss: 3.3094e-05 - accuracy: 1.0000 - val_loss: 6.8854 - val_accuracy: 0.4693
# Epoch 10/20
# 526/526 [==============================] - 29s 54ms/step - loss: 6.3614e-05 - accuracy: 1.0000 - val_loss: 7.2784 - val_accuracy: 0.4736
# Epoch 11/20
# 526/526 [==============================] - 30s 58ms/step - loss: 9.1801e-06 - accuracy: 1.0000 - val_loss: 7.5471 - val_accuracy: 0.4661
# Epoch 12/20
# 526/526 [==============================] - 29s 55ms/step - loss: 5.9482e-06 - accuracy: 1.0000 - val_loss: 7.6644 - val_accuracy: 0.4650
# Epoch 13/20
# 526/526 [==============================] - 29s 55ms/step - loss: 7.4694e-06 - accuracy: 1.0000 - val_loss: 7.6920 - val_accuracy: 0.4682
# Epoch 14/20
# 526/526 [==============================] - 28s 54ms/step - loss: 3.4091e-06 - accuracy: 1.0000 - val_loss: 7.9082 - val_accuracy: 0.4650
# Epoch 15/20
# 526/526 [==============================] - 28s 53ms/step - loss: 3.1246e-06 - accuracy: 1.0000 - val_loss: 8.1435 - val_accuracy: 0.4575
# Epoch 16/20
# 526/526 [==============================] - 28s 54ms/step - loss: 2.5704e-06 - accuracy: 1.0000 - val_loss: 8.2853 - val_accuracy: 0.4575
# Epoch 17/20
# 526/526 [==============================] - 28s 54ms/step - loss: 1.6747e-06 - accuracy: 1.0000 - val_loss: 8.3820 - val_accuracy: 0.4639
# Epoch 18/20
# 526/526 [==============================] - 30s 57ms/step - loss: 1.4188e-06 - accuracy: 1.0000 - val_loss: 8.5399 - val_accuracy: 0.4639
# Epoch 19/20
# 526/526 [==============================] - 28s 54ms/step - loss: 7.8500e-07 - accuracy: 1.0000 - val_loss: 8.8635 - val_accuracy: 0.4532
# Epoch 20/20
# 526/526 [==============================] - 31s 58ms/step - loss: 7.6728e-07 - accuracy: 1.0000 - val_loss: 8.7102 - val_accuracy: 0.4639

# %%
model.save('nutrition.h5')

# %%
from tensorflow.keras.models import load_model
from keras_preprocessing import image
from keras_preprocessing.image import load_img
from keras_preprocessing.image import img_to_array

# %%
model = load_model("nutrition.h5")
labels=['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON']

# %%
img=image.load_img('/content/drive/MyDrive/TEST_SET/APPLES/n07740461_10011.jpg',target_size=(64,64))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['APPLES','BANANA','ORANGE','PINEAPPLE','WATERMELON']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 75ms/step
# 'APPLES'
